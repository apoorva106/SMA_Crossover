# %%
import backtrader as bt
import backtrader.analyzers as btanalyzers
import matplotlib
import matplotlib.pyplot as plt
import yfinance as yf
import pandas as pd
import numpy as np
from cvxopt import matrix, solvers
from datetime import datetime
import quantstats as qstats
# %matplotlib inline

# Read the CSV file using pandas
df = pd.read_csv('prices.csv')

# Convert the date column to datetime format
df['date'] = pd.to_datetime(df['date'], format = '%Y-%m-%d')

stock_start_date = df['date'].min() # Earliest Start Date in all Stock Data Start Dates
stock_end_date = df['date'].max() # Latest End Date in all Stock Data Start Dates

starting_dict = {} # To hold Start Dates for all 25 stocks

# Creating a DataFrame with all combinations of tickers and dates
tickers = df['ticker'].unique()
dates = pd.date_range(start=stock_start_date, end=stock_end_date, freq='D')
index = pd.MultiIndex.from_product([tickers, dates], names=['ticker', 'date'])
dummy_df = pd.DataFrame(index=index).reset_index()

# Populating the starting_dict dictionary with the starting date of each stock
for ticker in tickers:
    starting_dict[ticker] = df[df['ticker'] == ticker]['date'].min()

# Adding 200 days to the starting date of each stock
for ticker in tickers:
    starting_dict[ticker] = starting_dict[ticker] + pd.Timedelta(days=200)

# Merging the dummy DataFrame with the original DataFrame on the 'ticker' and 'date' columns
merged_df = pd.merge(dummy_df, df, on=['ticker', 'date'], how='left')

# Backward filling missing values in the 'close' column with the next available value within each group of 'ticker'
merged_df[['close','open','high','low']] = merged_df.groupby('ticker')[['close','open','high','low']].fillna(method='bfill')

# Updating the original DataFrame with the merged DataFrame
df = merged_df

# Converting the 'date' column to a datetime object with the specified format again (this line is redundant)
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')

# Setting the 'date' column as the index of the DataFrame
df = df.set_index('date')

df

class MyStrategy(bt.Strategy):

    params = (
        ('sma_period', 200),  # SMA period
        ('lookback_period', 200),  # Lookback Period to calculate returns
        ('rebalance_day', 1)  # Rebalancing at the Start of Each Month
    )

    def __init__(self):
        self.first_trading_day = False
        self.current_month = None
        self.prev_month = None
        self.has_position = False
        self.start_date = starting_dict
        self.sma_200 = [bt.ind.SMA(data, period=self.params.sma_period) for data in self.datas]
        self.selected_stocks = []
        self.selected_data = []
        self.rebalance_dates = set()  # Store rebalance dates

    def filter_stocks(self):
        self.selected_data = []
        for i, d in enumerate(self.datas):
            if pd.Timestamp(d.datetime.date(0)) > self.start_date[d._name]:
                if self.datas[i].close[0] > self.sma_200[i][0]:
                    self.selected_data.append(d._name)

                elif self.datas[i].close[0] < self.sma_200[i][0]:
                    pass

        self.selected_stocks = [d for d in self.datas if d._name in self.selected_data]        


        if len(self.selected_stocks)>0:
            self.get_returns(self.selected_stocks)
            
        for stock in self.selected_stocks:
            first_day_of_month = stock.datetime.date().replace(day=1)
            self.rebalance_dates.add(first_day_of_month)

    def next(self):
        # Check if it's a rebalance day
        if self.data.datetime.date().day == self.params.rebalance_day:
            if self.data.datetime.date() in self.rebalance_dates:
                if self.selected_stocks:
                    print(f"\nSelected Stocks for {self.data.datetime.date()}:")
                    for stock in self.selected_stocks:
                        print(stock._name)

    def mean_variance_optimization(self,returns):
        n = returns.shape[1]
        Sigma = np.cov(returns.T)
        if Sigma.shape == ():
            Sigma = np.array([[Sigma]])
        P = matrix(Sigma)
        q = matrix(np.zeros((n, 1)))
        G = matrix(-np.eye(n))
        h = matrix(np.zeros((n, 1)))
        A = matrix(np.ones((1, n)))
        b = matrix(np.array([1.]))
        solvers.options['show_progress'] = False
        sol = solvers.qp(P, q, G, h, A, b)
        return np.array(sol['x']).flatten()
    

    def get_returns(self, selected_stocks):
        prices = np.zeros((self.params.lookback_period,len(selected_stocks)))
        returns = np.zeros((self.params.lookback_period,len(selected_stocks)))

        for i, d in enumerate(selected_stocks):
            prices[:, i] = d.close.get(size=self.params.lookback_period)
            returns[1:, i] = np.diff(prices[:, i]) / prices[:-1, i]

        weights = self.mean_variance_optimization(returns)

        self.place_order(weights, selected_stocks)

    def place_order(self, weights, selected_stocks):
    # Selling the stocks not selected
        for i, d in enumerate(self.datas):
            if d not in selected_stocks:
                self.order_target_percent(data=d, target=0.0)

        # Buying the selected ones
        date_printed = False  # Flag to track if date has been printed
        for i, d in enumerate(selected_stocks):
            stock_name = d._name
            weight = weights[i]
            self.order_target_percent(data=d, target=weight)

            # Display date if not printed yet
            if not date_printed:
                print(f"Date - {self.data.datetime.date()}")
                date_printed = True

            # Print stock name and weight
            print(f"{stock_name} - {weight:.2f}")
            
        print()  # Print a new line after each block of date
          
    def next(self):
        self.current_month = self.data.datetime.date().month
        if self.prev_month is None or self.current_month != self.prev_month:
            self.first_trading_day = True
        else:
            self.first_trading_day = False
        if self.first_trading_day:
            self.filter_stocks()

        self.prev_month = self.current_month


# Create an empty cerebro instance
cerebro = bt.Cerebro()

# Add your strategy to cerebro
cerebro.addstrategy(MyStrategy)

# Looping over each unique value in the 'ticker' column of the DataFrame
for ticker in df['ticker'].unique():
    # Creating a new DataFrame with only rows where the 'ticker' column is equal to the current ticker
    stock_df = df[df['ticker'] == ticker]
    
    # Creating a data feed from the new DataFrame using the 'bt.feeds.PandasData' class
    datafeed = bt.feeds.PandasData(dataname=stock_df,
                                  open='close',
                                  close='close',
                                  high='close',
                                  low='close',
                                  volume=None,
                                  openinterest=None,
                                  datetime=None,
                                  fromdate=datetime(2010, 1, 4),
                                  todate=datetime(2020, 6, 15))
    
    # Adding the data feed to the Cerebro instance with a name equal to the current ticker
    cerebro.adddata(datafeed, name=ticker)

# Set the cash for cerebro
cerebro.broker.setcash(100000.00)

# Adding the PyFolio analyzer to the Cerebro instance
cerebro.addanalyzer(bt.analyzers.PyFolio, _name='pyfolio')

# Run cerebro
strategy_run = cerebro.run()

print('Final Portfolio Value:', cerebro.broker.getvalue())

# Set the figure size for the plot
plt.rcParams['figure.figsize'] = [10,50]

# Update the font size for the plot
plt.rcParams.update({'font.size': 12})

# Analyze results and plot the backtest
cerebro.plot(volume=False)

# Get the final strategy object
strategy_final = strategy_run[-1]

# Get the pyfolio analyzer from the strategy
pyfolio_object = strategy_final.analyzers.getbyname('pyfolio')

# Retrieve various portfolio items from the pyfolio analyzer
stock_returns, positions, transactions, gross_lev = pyfolio_object.get_pf_items()

# Remove timezone information from the index of stock_returns
stock_returns.index = stock_returns.index.tz_convert(None)

# Generate full performance report using quantstats library
try:
    qstats.reports.full(stock_returns)
except TypeError:
    pass

plt.savefig('quant_stats_final.png')

import quantstats as qs

# Extract the PyFolio analyzer results from the strategy run
pyfolio_analyzer = strategy_run[0].analyzers.getbyname('pyfolio')
returns, positions, transactions, gross_lev = pyfolio_analyzer.get_pf_items()

# Convert the returns series to a DataFrame and reformat the index
returns_df = pd.DataFrame(returns)
returns_df.index = returns_df.index.tz_convert(None)

# Use QuantStats to generate a report and plot the results
qs.reports.html(returns_df['return'], output='report.html')
qs.plots.snapshot(returns_df['return'], title='Strategy Performance')
# Out:
# Date - 2010-08-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.17
# BAJFINANCE - 0.00
# BANKBARODA - 0.10
# HDFC - 0.08
# HDFCBANK - 0.20
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.02
# PFC - 0.13
# PNB - 0.18
# SBIN - 0.00
# SRTRANSFIN - 0.11
#
# Date - 2010-09-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.13
# BAJFINANCE - 0.00
# BANKBARODA - 0.09
# HDFC - 0.07
# HDFCBANK - 0.22
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.02
# PEL - 0.03
# PFC - 0.15
# PNB - 0.18
# SBIN - 0.00
# SRTRANSFIN - 0.10
#
# Date - 2010-10-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.11
# BAJFINANCE - 0.01
# BANKBARODA - 0.12
# HDFC - 0.05
# HDFCBANK - 0.22
# ICICIBANK - 0.00
# INDUSINDBK - 0.01
# KOTAKBANK - 0.01
# PEL - 0.05
# PFC - 0.12
# PNB - 0.18
# SBIN - 0.00
# SRTRANSFIN - 0.10
#
# Date - 2010-11-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.02
# BAJAJHLDNG - 0.09
# BAJFINANCE - 0.00
# BANKBARODA - 0.14
# HDFC - 0.03
# HDFCBANK - 0.23
# ICICIBANK - 0.00
# INDUSINDBK - 0.03
# KOTAKBANK - 0.01
# PFC - 0.11
# PNB - 0.20
# SBIN - 0.00
# SRTRANSFIN - 0.14
#
# Date - 2010-12-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.11
# BAJAJHLDNG - 0.14
# BAJFINANCE - 0.05
# BANKBARODA - 0.13
# HDFC - 0.06
# HDFCBANK - 0.20
# ICICIBANK - 0.00
# INDUSINDBK - 0.06
# KOTAKBANK - 0.04
# PFC - 0.08
# PNB - 0.01
# SBIN - 0.00
# SRTRANSFIN - 0.12
#
# Date - 2011-01-01
# BAJAJFINSV - 0.19
# BAJAJHLDNG - 0.13
# BAJFINANCE - 0.05
# BANKBARODA - 0.14
# HDFC - 0.10
# HDFCBANK - 0.19
# ICICIBANK - 0.00
# INDUSINDBK - 0.04
# KOTAKBANK - 0.05
# PNB - 0.04
# SRTRANSFIN - 0.06
#
# Date - 2011-03-01
# SRTRANSFIN - 1.00
#
# Date - 2011-04-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.13
# BANKBARODA - 0.32
# HDFC - 0.09
# HDFCBANK - 0.21
# ICICIBANK - 0.00
# INDUSINDBK - 0.05
# KOTAKBANK - 0.05
# SRTRANSFIN - 0.16
#
# Date - 2011-05-01
# BAJAJFINSV - 0.09
# BAJFINANCE - 0.14
# HDFC - 0.13
# HDFCBANK - 0.11
# ICICIBANK - 0.09
# PEL - 0.44
#
# Date - 2011-06-01
# BAJAJFINSV - 0.17
# HDFC - 0.20
# HDFCBANK - 0.30
# ICICIBANK - 0.08
# INDUSINDBK - 0.04
# KOTAKBANK - 0.21
#
# Date - 2011-07-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.06
# BAJAJHLDNG - 0.40
# BAJFINANCE - 0.04
# BANKBARODA - 0.13
# HDFC - 0.01
# HDFCBANK - 0.10
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.10
# PNB - 0.16
# SBIN - 0.00
#
# Date - 2011-08-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.03
# BAJAJHLDNG - 0.42
# BAJFINANCE - 0.01
# BANKBARODA - 0.06
# HDFC - 0.01
# HDFCBANK - 0.23
# ICICIBANK - 0.00
# INDUSINDBK - 0.01
# KOTAKBANK - 0.09
# PNB - 0.14
# SBIN - 0.00
#
# Date - 2011-09-01
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.55
# BAJFINANCE - 0.04
# HDFCBANK - 0.19
# KOTAKBANK - 0.21
#
# Date - 2011-10-01
# BAJFINANCE - 1.00
#
# Date - 2011-11-01
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.68
# BAJFINANCE - 0.03
# HDFC - 0.03
# HDFCBANK - 0.16
# INDUSINDBK - 0.00
# KOTAKBANK - 0.09
#
# Date - 2011-12-01
# BAJFINANCE - 0.29
# KOTAKBANK - 0.71
#
# Date - 2012-01-01
# PEL - 1.00
#
# Date - 2012-02-01
# AXISBANK - 0.00
# BAJFINANCE - 0.20
# HDFC - 0.12
# HDFCBANK - 0.09
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.46
# PFC - 0.00
# PNB - 0.05
# SBIN - 0.00
# SRTRANSFIN - 0.09
#
# Date - 2012-03-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.34
# BAJFINANCE - 0.11
# BANKBARODA - 0.00
# HDFC - 0.08
# HDFCBANK - 0.13
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.06
# PEL - 0.28
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
#
# Date - 2012-04-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.35
# BAJFINANCE - 0.07
# BANKBARODA - 0.00
# HDFC - 0.06
# HDFCBANK - 0.10
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.33
# PFC - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.07
#
# Date - 2012-05-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.35
# BAJFINANCE - 0.07
# HDFC - 0.06
# HDFCBANK - 0.13
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.33
# SBIN - 0.00
# SRTRANSFIN - 0.06
#
# Date - 2012-06-01
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.37
# BAJFINANCE - 0.22
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.04
# PEL - 0.36
# SBIN - 0.00
#
# Date - 2012-07-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.30
# BAJFINANCE - 0.12
# BANKBARODA - 0.00
# HDFC - 0.31
# HDFCBANK - 0.09
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.17
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
#
# Date - 2012-08-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.30
# BAJFINANCE - 0.08
# HDFC - 0.32
# HDFCBANK - 0.09
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.19
# PFC - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.01
#
# Date - 2012-09-01
# BAJAJFINSV - 0.09
# BAJFINANCE - 0.12
# HDFC - 0.41
# HDFCBANK - 0.26
# ICICIBANK - 0.00
# KOTAKBANK - 0.07
# SRTRANSFIN - 0.05
#
# Date - 2012-10-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.28
# BAJFINANCE - 0.08
# BANKBARODA - 0.00
# HDFC - 0.20
# HDFCBANK - 0.11
# ICICIBANK - 0.00
# INDUSINDBK - 0.01
# KOTAKBANK - 0.00
# L&TFH - 0.31
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.01
#
# Date - 2012-11-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.16
# BAJFINANCE - 0.06
# BANKBARODA - 0.00
# HDFC - 0.18
# HDFCBANK - 0.07
# ICICIBANK - 0.00
# INDUSINDBK - 0.03
# KOTAKBANK - 0.00
# L&TFH - 0.27
# PEL - 0.18
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.04
#
# Date - 2012-12-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.18
# BAJFINANCE - 0.11
# BANKBARODA - 0.00
# HDFC - 0.15
# HDFCBANK - 0.10
# ICICIBANK - 0.00
# INDUSINDBK - 0.07
# KOTAKBANK - 0.02
# L&TFH - 0.07
# PEL - 0.18
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.12
#
# Date - 2013-01-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.13
# BAJFINANCE - 0.09
# BANKBARODA - 0.00
# HDFC - 0.10
# HDFCBANK - 0.24
# ICICIBANK - 0.00
# INDUSINDBK - 0.02
# KOTAKBANK - 0.07
# L&TFH - 0.03
# PEL - 0.13
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.01
# SRTRANSFIN - 0.17
#
# Date - 2013-02-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.11
# BAJFINANCE - 0.13
# BANKBARODA - 0.00
# HDFC - 0.05
# HDFCBANK - 0.28
# ICICIBANK - 0.00
# INDUSINDBK - 0.01
# KOTAKBANK - 0.08
# L&TFH - 0.02
# PEL - 0.10
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.20
#
# Date - 2013-03-01
# AXISBANK - 0.00
# BAJAJHLDNG - 0.20
# BAJFINANCE - 0.20
# INDUSINDBK - 0.05
# KOTAKBANK - 0.23
# L&TFH - 0.01
# PEL - 0.16
# PFC - 0.00
# SRTRANSFIN - 0.15
#
# Date - 2013-04-01
# AXISBANK - 0.11
# BAJAJHLDNG - 0.25
# HDFC - 0.09
# INDUSINDBK - 0.03
# KOTAKBANK - 0.27
# L&TFH - 0.02
# PEL - 0.18
# SRTRANSFIN - 0.06
#
# Date - 2013-05-01
# AXISBANK - 0.11
# HDFC - 0.06
# HDFCBANK - 0.40
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.25
# L&TFH - 0.00
# PFC - 0.00
# SBIN - 0.03
# SRTRANSFIN - 0.14
#
# Date - 2013-06-01
# AXISBANK - 0.14
# BAJFINANCE - 0.13
# HDFC - 0.04
# HDFCBANK - 0.32
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.24
# SBIN - 0.02
# SRTRANSFIN - 0.10
#
# Date - 2013-07-01
# BAJFINANCE - 0.15
# HDFC - 0.09
# HDFCBANK - 0.27
# ICICIBANK - 0.06
# INDUSINDBK - 0.00
# KOTAKBANK - 0.20
# PEL - 0.15
# PNB - 0.02
# SBIN - 0.05
#
# Date - 2013-08-01
# PEL - 1.00
#
# Date - 2013-09-01
# PEL - 1.00
#
# Date - 2013-10-01
# PEL - 1.00
#
# Date - 2013-11-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.29
# BAJAJHLDNG - 0.37
# BAJFINANCE - 0.01
# BANKBARODA - 0.00
# HDFC - 0.00
# HDFCBANK - 0.11
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.02
# L&TFH - 0.05
# PEL - 0.11
# PNB - 0.00
# SBIN - 0.03
#
# Date - 2013-12-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.31
# BAJAJHLDNG - 0.41
# BAJFINANCE - 0.02
# BANKBARODA - 0.00
# HDFC - 0.00
# HDFCBANK - 0.16
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.07
# PFC - 0.00
# SBIN - 0.04
#
# Date - 2014-01-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.26
# BAJAJHLDNG - 0.44
# BAJFINANCE - 0.03
# BANKBARODA - 0.00
# HDFC - 0.01
# HDFCBANK - 0.06
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.05
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.12
# SRTRANSFIN - 0.03
#
# Date - 2014-02-01
# BAJAJFINSV - 0.26
# BAJAJHLDNG - 0.49
# BAJFINANCE - 0.09
# BANKBARODA - 0.01
# HDFC - 0.10
# PNB - 0.00
# SRTRANSFIN - 0.03
#
# Date - 2014-03-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.25
# BAJAJHLDNG - 0.61
# BAJFINANCE - 0.06
# BANKBARODA - 0.00
# HDFC - 0.06
# HDFCBANK - 0.02
# ICICIBANK - 0.00
# L&TFH - 0.00
# PFC - 0.00
# PNB - 0.00
#
# Date - 2014-04-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.09
# BAJAJHLDNG - 0.43
# BAJFINANCE - 0.09
# BANKBARODA - 0.00
# HDFC - 0.35
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.02
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.02
#
# Date - 2014-05-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.14
# BAJAJHLDNG - 0.44
# BAJFINANCE - 0.16
# BANKBARODA - 0.00
# HDFCBANK - 0.22
# IBULHSGFIN - 0.03
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.01
#
# Date - 2014-06-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.10
# BAJFINANCE - 0.05
# BANKBARODA - 0.00
# HDFC - 0.80
# HDFCBANK - 0.01
# IBULHSGFIN - 0.02
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.00
# PEL - 0.01
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2014-07-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.10
# BAJAJHLDNG - 0.20
# BAJFINANCE - 0.10
# BANKBARODA - 0.00
# HDFCBANK - 0.36
# IBULHSGFIN - 0.02
# ICICIBANK - 0.00
# INDUSINDBK - 0.01
# KOTAKBANK - 0.00
# L&TFH - 0.01
# PEL - 0.19
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2014-08-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.01
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.95
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.01
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2014-09-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.01
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.95
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.01
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2014-10-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.01
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.95
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.01
# PEL - 0.01
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2014-11-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.01
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.95
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.00
# PEL - 0.01
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2014-12-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.01
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.95
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.01
# KOTAKBANK - 0.00
# L&TFH - 0.00
# PEL - 0.01
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2015-01-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.01
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.95
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.01
# KOTAKBANK - 0.00
# PEL - 0.00
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2015-02-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.05
# BAJAJHLDNG - 0.17
# BAJFINANCE - 0.03
# HDFCBANK - 0.37
# IBULHSGFIN - 0.02
# ICICIBANK - 0.00
# INDUSINDBK - 0.17
# KOTAKBANK - 0.00
# L&TFH - 0.04
# PEL - 0.13
# PFC - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2015-03-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.05
# BAJFINANCE - 0.04
# HDFCBANK - 0.49
# IBULHSGFIN - 0.04
# ICICIBANK - 0.00
# INDUSINDBK - 0.12
# KOTAKBANK - 0.07
# PEL - 0.19
# PFC - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2015-04-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJFINANCE - 0.00
# HDFC - 0.97
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.00
# PFC - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2015-05-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJFINANCE - 0.00
# HDFC - 0.98
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.00
# PFC - 0.00
#
# Date - 2015-06-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJFINANCE - 0.00
# HDFC - 0.98
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.00
#
# Date - 2015-07-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.00
# BAJFINANCE - 0.00
# HDFC - 0.97
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.00
# PEL - 0.00
#
# Date - 2015-08-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.02
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.95
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.00
# PEL - 0.00
# PNB - 0.00
# SBIN - 0.00
#
# Date - 2015-09-01
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.02
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.97
# IBULHSGFIN - 0.01
# PEL - 0.00
#
# Date - 2015-10-01
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.01
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.96
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# INDUSINDBK - 0.00
# L&TFH - 0.00
# SRTRANSFIN - 0.01
#
# Date - 2015-11-01
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.01
# BAJFINANCE - 0.00
# HDFC - 0.96
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.00
# PEL - 0.00
# SRTRANSFIN - 0.01
#
# Date - 2015-12-01
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.01
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.95
# HDFCBANK - 0.00
# IBULHSGFIN - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.00
# PEL - 0.00
# PNB - 0.00
# SRTRANSFIN - 0.01
#
# Date - 2016-01-01
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.24
# BAJFINANCE - 0.05
# HDFC - 0.02
# HDFCBANK - 0.57
# IBULHSGFIN - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# PEL - 0.11
#
# Date - 2016-02-01
# BAJFINANCE - 0.19
# HDFC - 0.05
# IBULHSGFIN - 0.05
# INDUSINDBK - 0.31
# KOTAKBANK - 0.19
# PEL - 0.21
#
# Date - 2016-03-01
# BAJFINANCE - 0.81
# HDFC - 0.19
#
# Date - 2016-04-01
# AXISBANK - 0.00
# BAJFINANCE - 0.06
# HDFC - 0.02
# HDFCBANK - 0.72
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.09
# PEL - 0.10
# SRTRANSFIN - 0.00
#
# Date - 2016-05-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.07
# BAJFINANCE - 0.04
# BANKBARODA - 0.00
# HDFC - 0.01
# HDFCBANK - 0.73
# IBULHSGFIN - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.07
# PEL - 0.08
# PFC - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2016-06-01
# AXISBANK - 0.00
# BAJAJHLDNG - 0.21
# BAJFINANCE - 0.01
# HDFC - 0.00
# HDFCBANK - 0.63
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.06
# PEL - 0.09
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2016-07-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.04
# BAJAJHLDNG - 0.17
# BAJFINANCE - 0.01
# BANKBARODA - 0.00
# HDFC - 0.00
# HDFCBANK - 0.62
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.04
# PEL - 0.11
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.01
#
# Date - 2016-08-01
# AXISBANK - 0.02
# BAJAJFINSV - 0.05
# BAJAJHLDNG - 0.15
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.02
# HDFCBANK - 0.59
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.00
# L&TFH - 0.04
# PEL - 0.12
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.03
#
# Date - 2016-09-01
# AXISBANK - 0.02
# BAJAJFINSV - 0.07
# BAJAJHLDNG - 0.18
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.06
# HDFCBANK - 0.37
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.02
# KOTAKBANK - 0.07
# L&TFH - 0.05
# PEL - 0.11
# PFC - 0.02
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.02
#
# Date - 2016-10-01
# AXISBANK - 0.05
# BAJAJFINSV - 0.04
# BAJAJHLDNG - 0.19
# BAJFINANCE - 0.01
# BANKBARODA - 0.00
# HDFC - 0.01
# HDFCBANK - 0.46
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.11
# L&TFH - 0.01
# PEL - 0.10
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.01
#
# Date - 2016-11-01
# BAJAJFINSV - 0.04
# BAJAJHLDNG - 0.17
# BAJFINANCE - 0.02
# HDFC - 0.01
# HDFCBANK - 0.41
# IBULHSGFIN - 0.02
# ICICIBANK - 0.01
# INDUSINDBK - 0.05
# KOTAKBANK - 0.16
# L&TFH - 0.00
# PEL - 0.10
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.01
#
# Date - 2016-12-01
# BAJAJFINSV - 0.18
# BAJAJHLDNG - 0.26
# BANKBARODA - 0.08
# IBULHSGFIN - 0.16
# ICICIBANK - 0.18
# L&TFH - 0.00
# PFC - 0.10
# PNB - 0.00
# SBIN - 0.03
#
# Date - 2017-01-01
# BAJAJFINSV - 0.48
# PFC - 0.52
#
# Date - 2017-02-01
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.13
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.01
# HDFCBANK - 0.68
# IBULHSGFIN - 0.02
# ICICIBANK - 0.02
# INDUSINDBK - 0.00
# KOTAKBANK - 0.12
# L&TFH - 0.00
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.01
#
# Date - 2017-03-01
# AXISBANK - 0.04
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.14
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.03
# HDFCBANK - 0.56
# IBULHSGFIN - 0.03
# ICICIBANK - 0.01
# INDUSINDBK - 0.00
# KOTAKBANK - 0.15
# L&TFH - 0.00
# PEL - 0.00
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.04
#
# Date - 2017-04-01
# AXISBANK - 0.08
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.14
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.02
# HDFCBANK - 0.56
# IBULHSGFIN - 0.00
# ICICIBANK - 0.01
# INDUSINDBK - 0.00
# KOTAKBANK - 0.18
# L&TFH - 0.00
# PEL - 0.00
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.02
# SRTRANSFIN - 0.00
#
# Date - 2017-05-01
# AXISBANK - 0.05
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.10
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.05
# HDFCBANK - 0.43
# IBULHSGFIN - 0.00
# ICICIBANK - 0.01
# ICICIPRULI - 0.14
# INDUSINDBK - 0.00
# KOTAKBANK - 0.17
# L&TFH - 0.00
# PEL - 0.00
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.03
# SRTRANSFIN - 0.00
#
# Date - 2017-06-01
# AXISBANK - 0.08
# BAJAJFINSV - 0.01
# BAJAJHLDNG - 0.12
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.08
# HDFCBANK - 0.42
# IBULHSGFIN - 0.00
# ICICIBANK - 0.02
# ICICIPRULI - 0.16
# INDUSINDBK - 0.00
# KOTAKBANK - 0.10
# L&TFH - 0.00
# PEL - 0.00
# PNB - 0.00
# SBIN - 0.01
# SRTRANSFIN - 0.00
#
# Date - 2017-07-01
# AXISBANK - 0.05
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.16
# BAJFINANCE - 0.00
# HDFC - 0.06
# HDFCBANK - 0.40
# IBULHSGFIN - 0.04
# ICICIBANK - 0.02
# ICICIPRULI - 0.12
# INDUSINDBK - 0.00
# KOTAKBANK - 0.13
# L&TFH - 0.00
# PEL - 0.00
# SBIN - 0.01
# SRTRANSFIN - 0.00
#
# Date - 2017-08-01
# AXISBANK - 0.05
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.16
# BAJFINANCE - 0.00
# HDFC - 0.02
# HDFCBANK - 0.38
# IBULHSGFIN - 0.06
# ICICIBANK - 0.02
# ICICIPRULI - 0.11
# INDUSINDBK - 0.04
# KOTAKBANK - 0.11
# L&TFH - 0.00
# PEL - 0.01
# PNB - 0.00
# SBIN - 0.01
# SRTRANSFIN - 0.01
#
# Date - 2017-09-01
# AXISBANK - 0.08
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.13
# BAJFINANCE - 0.00
# HDFC - 0.06
# HDFCBANK - 0.35
# IBULHSGFIN - 0.01
# ICICIBANK - 0.04
# ICICIPRULI - 0.08
# INDUSINDBK - 0.08
# KOTAKBANK - 0.16
# L&TFH - 0.00
# PEL - 0.00
# SRTRANSFIN - 0.01
#
# Date - 2017-10-01
# AXISBANK - 0.11
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.10
# BAJFINANCE - 0.00
# HDFC - 0.08
# HDFCBANK - 0.38
# IBULHSGFIN - 0.03
# INDUSINDBK - 0.07
# KOTAKBANK - 0.18
# L&TFH - 0.00
# PEL - 0.01
# SRTRANSFIN - 0.04
#
# Date - 2017-11-01
# AXISBANK - 0.03
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.10
# BAJFINANCE - 0.00
# BANKBARODA - 0.01
# HDFC - 0.12
# HDFCBANK - 0.37
# IBULHSGFIN - 0.04
# ICICIBANK - 0.12
# INDUSINDBK - 0.03
# KOTAKBANK - 0.12
# L&TFH - 0.00
# PFC - 0.02
# PNB - 0.00
# SBIN - 0.01
# SRTRANSFIN - 0.04
#
# Date - 2017-12-01
# AXISBANK - 0.06
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.13
# BAJFINANCE - 0.00
# BANKBARODA - 0.02
# HDFCBANK - 0.49
# ICICIBANK - 0.11
# INDUSINDBK - 0.02
# KOTAKBANK - 0.15
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.02
#
# Date - 2018-01-01
# AXISBANK - 0.06
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.16
# BAJFINANCE - 0.00
# BANKBARODA - 0.03
# HDFCBANK - 0.59
# IBULHSGFIN - 0.03
# ICICIBANK - 0.10
# PEL - 0.02
# PFC - 0.00
# PNB - 0.00
# SBIN - 0.00
# SRTRANSFIN - 0.01
#
# Date - 2018-02-01
# AXISBANK - 0.05
# BAJAJHLDNG - 0.13
# HDFC - 0.01
# HDFCBANK - 0.44
# IBULHSGFIN - 0.01
# ICICIBANK - 0.06
# ICICIPRULI - 0.05
# INDUSINDBK - 0.05
# KOTAKBANK - 0.13
# PNB - 0.00
# SBIN - 0.05
# SRTRANSFIN - 0.02
#
# Date - 2018-03-01
# HDFC - 0.06
# HDFCBANK - 0.62
# IBULHSGFIN - 0.00
# ICICIPRULI - 0.15
# INDUSINDBK - 0.05
# KOTAKBANK - 0.05
# SRTRANSFIN - 0.06
#
# Date - 2018-04-01
# BAJAJFINSV - 0.11
# BAJFINANCE - 0.00
# HDFC - 0.08
# HDFCBANK - 0.57
# IBULHSGFIN - 0.00
# INDUSINDBK - 0.17
# KOTAKBANK - 0.04
# SRTRANSFIN - 0.03
#
# Date - 2018-05-01
# BAJAJFINSV - 0.00
# BAJFINANCE - 0.00
# HDFC - 0.00
# HDFCBANK - 0.53
# IBULHSGFIN - 0.00
# ICICIPRULI - 0.06
# INDUSINDBK - 0.18
# KOTAKBANK - 0.00
# L&TFH - 0.00
# SBILIFE - 0.21
# SRTRANSFIN - 0.02
#
# Date - 2018-06-01
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.27
# BAJFINANCE - 0.00
# HDFC - 0.04
# HDFCBANK - 0.32
# IBULHSGFIN - 0.00
# ICICIPRULI - 0.07
# INDUSINDBK - 0.13
# KOTAKBANK - 0.11
# SRTRANSFIN - 0.04
#
# Date - 2018-07-01
# BAJAJFINSV - 0.03
# BAJAJHLDNG - 0.27
# BAJFINANCE - 0.00
# HDFC - 0.08
# HDFCBANK - 0.34
# INDUSINDBK - 0.16
# KOTAKBANK - 0.11
#
# Date - 2018-08-01
# AXISBANK - 0.01
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.11
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# GICRE - 0.14
# HDFC - 0.01
# HDFCBANK - 0.28
# HDFCLIFE - 0.01
# IBULHSGFIN - 0.00
# ICICIBANK - 0.01
# ICICIGI - 0.11
# ICICIPRULI - 0.00
# INDUSINDBK - 0.14
# KOTAKBANK - 0.03
# L&TFH - 0.00
# PEL - 0.03
# SBILIFE - 0.11
# SBIN - 0.01
#
# Date - 2018-09-01
# AXISBANK - 0.06
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.15
# BAJFINANCE - 0.00
# BANKBARODA - 0.00
# HDFC - 0.11
# HDFCBANK - 0.26
# IBULHSGFIN - 0.00
# ICICIBANK - 0.02
# ICICIGI - 0.11
# INDUSINDBK - 0.18
# KOTAKBANK - 0.07
# L&TFH - 0.00
# PEL - 0.04
# PFC - 0.00
# SBIN - 0.00
#
# Date - 2018-10-01
# AXISBANK - 0.11
# BAJAJHLDNG - 0.23
# HDFCBANK - 0.53
# ICICIBANK - 0.04
# ICICIGI - 0.08
# SBIN - 0.00
#
# Date - 2018-11-01
# AXISBANK - 0.23
# BAJFINANCE - 0.16
# ICICIBANK - 0.08
# ICICIGI - 0.35
# PFC - 0.00
# SBIN - 0.18
#
# Date - 2018-12-01
# AXISBANK - 0.09
# BAJAJHLDNG - 0.15
# BAJFINANCE - 0.00
# HDFC - 0.00
# HDFCBANK - 0.59
# ICICIBANK - 0.08
# ICICIGI - 0.09
# PFC - 0.00
# SBIN - 0.00
#
# Date - 2019-01-01
# AXISBANK - 0.05
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.11
# BAJFINANCE - 0.00
# BANDHANBNK - 0.00
# BANKBARODA - 0.00
# HDFC - 0.00
# HDFCBANK - 0.58
# ICICIBANK - 0.04
# ICICIGI - 0.07
# KOTAKBANK - 0.09
# L&TFH - 0.00
# PFC - 0.00
# PNB - 0.04
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2019-02-01
# AXISBANK - 0.05
# BAJFINANCE - 0.00
# HDFC - 0.00
# HDFCBANK - 0.65
# ICICIBANK - 0.11
# ICICIGI - 0.08
# KOTAKBANK - 0.10
# PFC - 0.00
#
# Date - 2019-03-01
# AXISBANK - 0.07
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.11
# BAJFINANCE - 0.00
# HDFCBANK - 0.55
# ICICIBANK - 0.04
# ICICIGI - 0.03
# KOTAKBANK - 0.06
# PEL - 0.00
# PFC - 0.00
# PNB - 0.01
# SBILIFE - 0.13
# SRTRANSFIN - 0.00
#
# Date - 2019-04-01
# AXISBANK - 0.04
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.09
# BAJFINANCE - 0.00
# BANDHANBNK - 0.00
# BANKBARODA - 0.00
# HDFC - 0.00
# HDFCAMC - 0.00
# HDFCBANK - 0.52
# HDFCLIFE - 0.09
# IBULHSGFIN - 0.00
# ICICIBANK - 0.01
# ICICIGI - 0.02
# ICICIPRULI - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.05
# L&TFH - 0.00
# PEL - 0.00
# PFC - 0.04
# PNB - 0.00
# SBILIFE - 0.13
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2019-05-01
# AXISBANK - 0.03
# BAJAJFINSV - 0.04
# BAJAJHLDNG - 0.09
# BAJFINANCE - 0.00
# BANDHANBNK - 0.00
# BANKBARODA - 0.00
# HDFC - 0.00
# HDFCAMC - 0.03
# HDFCBANK - 0.42
# HDFCLIFE - 0.08
# ICICIBANK - 0.00
# ICICIGI - 0.07
# ICICIPRULI - 0.00
# KOTAKBANK - 0.04
# PEL - 0.00
# PFC - 0.05
# PNB - 0.00
# SBILIFE - 0.14
# SBIN - 0.00
#
# Date - 2019-06-01
# AXISBANK - 0.05
# BAJAJFINSV - 0.04
# BAJAJHLDNG - 0.11
# BAJFINANCE - 0.00
# BANDHANBNK - 0.00
# BANKBARODA - 0.00
# HDFC - 0.00
# HDFCAMC - 0.10
# HDFCBANK - 0.39
# HDFCLIFE - 0.09
# IBULHSGFIN - 0.00
# ICICIBANK - 0.00
# ICICIGI - 0.06
# ICICIPRULI - 0.00
# INDUSINDBK - 0.00
# KOTAKBANK - 0.01
# PFC - 0.03
# PNB - 0.00
# SBILIFE - 0.12
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2019-07-01
# AXISBANK - 0.06
# BAJAJFINSV - 0.08
# BAJAJHLDNG - 0.12
# BAJFINANCE - 0.00
# BANDHANBNK - 0.00
# BANKBARODA - 0.00
# HDFC - 0.00
# HDFCAMC - 0.13
# HDFCBANK - 0.29
# HDFCLIFE - 0.07
# ICICIBANK - 0.00
# ICICIGI - 0.03
# ICICIPRULI - 0.00
# KOTAKBANK - 0.12
# PFC - 0.03
# SBILIFE - 0.07
# SBIN - 0.00
#
# Date - 2019-08-01
# BAJAJHLDNG - 0.12
# BAJFINANCE - 0.00
# HDFC - 0.16
# HDFCAMC - 0.12
# HDFCLIFE - 0.08
# ICICIBANK - 0.06
# ICICIGI - 0.02
# ICICIPRULI - 0.00
# KOTAKBANK - 0.24
# SBILIFE - 0.18
# SBIN - 0.00
#
# Date - 2019-09-01
# BAJFINANCE - 0.03
# HDFC - 0.33
# HDFCAMC - 0.15
# HDFCLIFE - 0.10
# ICICIGI - 0.09
# ICICIPRULI - 0.06
# SBILIFE - 0.25
#
# Date - 2019-10-01
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.11
# BAJFINANCE - 0.00
# GICRE - 0.10
# HDFCAMC - 0.06
# HDFCBANK - 0.14
# HDFCLIFE - 0.07
# ICICIBANK - 0.00
# ICICIGI - 0.06
# ICICIPRULI - 0.04
# KOTAKBANK - 0.18
# SBILIFE - 0.23
#
# Date - 2019-11-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.21
# BAJFINANCE - 0.00
# BANDHANBNK - 0.00
# GICRE - 0.02
# HDFC - 0.06
# HDFCAMC - 0.05
# HDFCBANK - 0.05
# HDFCLIFE - 0.12
# ICICIBANK - 0.00
# ICICIGI - 0.07
# ICICIPRULI - 0.06
# KOTAKBANK - 0.18
# NIACL - 0.00
# SBILIFE - 0.18
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2019-12-01
# AXISBANK - 0.00
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.22
# BAJFINANCE - 0.00
# BANDHANBNK - 0.00
# GICRE - 0.02
# HDFC - 0.07
# HDFCAMC - 0.04
# HDFCBANK - 0.06
# HDFCLIFE - 0.11
# ICICIBANK - 0.00
# ICICIGI - 0.07
# ICICIPRULI - 0.06
# INDUSINDBK - 0.00
# KOTAKBANK - 0.17
# L&TFH - 0.00
# NIACL - 0.00
# PFC - 0.00
# SBILIFE - 0.18
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2020-01-01
# AXISBANK - 0.03
# BAJAJFINSV - 0.00
# BAJFINANCE - 0.00
# GICRE - 0.02
# HDFC - 0.15
# HDFCAMC - 0.02
# HDFCBANK - 0.11
# HDFCLIFE - 0.10
# ICICIBANK - 0.00
# ICICIGI - 0.07
# ICICIPRULI - 0.16
# INDUSINDBK - 0.00
# KOTAKBANK - 0.17
# L&TFH - 0.00
# NIACL - 0.00
# PFC - 0.04
# SBILIFE - 0.13
# SBIN - 0.00
# SRTRANSFIN - 0.00
#
# Date - 2020-02-01
# BAJAJFINSV - 0.00
# BAJAJHLDNG - 0.27
# BAJFINANCE - 0.00
# GICRE - 0.03
# HDFC - 0.13
# HDFCAMC - 0.01
# ICICIBANK - 0.01
# ICICIGI - 0.16
# KOTAKBANK - 0.19
# L&TFH - 0.00
# NIACL - 0.00
# PFC - 0.00
# SBILIFE - 0.21
#
# Date - 2020-03-01
# BAJAJFINSV - 0.36
# BAJFINANCE - 0.01
# HDFCAMC - 0.14
# ICICIBANK - 0.27
# PFC - 0.17
# SRTRANSFIN - 0.06
#
# Date - 2020-06-01
# ICICIGI - 1.00
#
# Final Portfolio Value: 353605.585811615
# <div id='92af5c3b-1c10-4e10-8b90-e5e50e552948'></div>
# <h4>Performance Metrics</h4>
#                            Strategy
# -------------------------  ----------
# Start Period               2010-01-04
# End Period                 2020-06-15
# Risk-Free Rate             0.0%
# Time in Market             64.0%
#
# Cumulative Return          253.61%
# CAGR﹪                     12.84%
#
# Sharpe                     0.51
# Prob. Sharpe Ratio         99.1%
# Smart Sharpe               0.51
# Sortino                    0.89
# Smart Sortino              0.89
# Sortino/√2                 0.63
# Smart Sortino/√2           0.63
# Omega                      1.17
#
# Max Drawdown               -49.13%
# Longest DD Days            606
# Volatility (ann.)          19.86%
# Calmar                     0.26
# Skew                       13.79
# Kurtosis                   584.63
#
# Expected Daily %           0.03%
# Expected Monthly %         1.01%
# Expected Yearly %          12.17%
# Kelly Criterion            7.77%
# Risk of Ruin               0.0%
# Daily Value-at-Risk        -2.02%
# Expected Shortfall (cVaR)  -2.02%
#
# Max Consecutive Wins       5
# Max Consecutive Losses     5
# Gain/Pain Ratio            0.17
# Gain/Pain (1M)             0.74
#
# Payoff Ratio               1.05
# Profit Factor              1.17
# Common Sense Ratio         1.31
# CPC Index                  0.65
# Tail Ratio                 1.12
# Outlier Win Ratio          7.47
# Outlier Loss Ratio         3.33
#
# MTD                        5.46%
# 3M                         -15.31%
# 6M                         -36.95%
# YTD                        -37.88%
# 1Y                         -32.73%
# 3Y (ann.)                  -4.91%
# 5Y (ann.)                  13.81%
# 10Y (ann.)                 13.45%
# All-time (ann.)            12.84%
#
# Best Day                   48.06%
# Worst Day                  -18.21%
# Best Month                 52.23%
# Worst Month                -36.59%
# Best Year                  62.27%
# Worst Year                 -37.88%
#
# Avg. Drawdown              -2.6%
# Avg. Drawdown Days         28
# Recovery Factor            5.16
# Ulcer Index                0.11
# Serenity Index             1.35
#
# Avg. Up Month              4.69%
# Avg. Down Month            -4.99%
# Win Days %                 52.67%
# Win Month %                65.55%
# Win Quarter %              70.0%
# Win Year %                 72.73%
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2019-10-31  2020-05-23  2020-06-15   228    -49.126128        -48.716424
# 2  2013-05-31  2013-12-17  2014-07-24   419    -25.222211        -24.519905
# 3  2010-11-05  2011-10-05  2012-07-03   606    -22.682982        -21.031479
# 4  2016-09-24  2016-12-24  2017-03-30   187    -20.100408        -18.742708
# 5  2018-07-28  2018-10-09  2019-05-01   277    -16.781503        -15.378030
# <h4>Strategy Visualization</h4>
# <div id='e1a52edb-9638-43cf-9bf4-e4f599f1b502'></div>
# <div id='0bd79e87-cfba-4460-a72a-9df37d01e7bb'></div>
# <div id='1f2f3051-1f69-44d0-ab9a-e66818358ac9'></div>
# <div id='800c82a8-4311-43b5-88e5-a4adb281f9ad'></div>
# <div id='34e92331-3682-4847-add8-01eefcc52ccf'></div>
# <div id='ef9f929d-e727-4488-b2ce-030b15b5d7e8'></div>
# <div id='2344e3af-b16a-455d-a1fa-e4c56bfd3092'></div>
# <div id='5d31bdbe-ebfc-493c-b2c0-c85f01f0bf2d'></div>
# <div id='a896b565-0d4b-4148-a8be-d02966e5391d'></div>
# <div id='adf90054-f878-4f88-a6bb-6dd0d2e736f6'></div>
# <div id='9dd3de86-ad71-4775-975d-3982ed663cc7'></div>
# <div id='20f17d8e-8200-4c07-85fa-da40a1b2709f'></div>
# <div id='4432e79d-667e-4d71-9053-a6a8f954bcec'></div>
# <div id='2261a255-f8e4-4f7e-967e-381bbee79651'></div>
# <div id='aeaa729d-8948-4b79-a677-e14a73565871'></div>
# <div id='6decada7-8882-455e-820d-983db77939d3'></div>
# <div id='52536c38-cb8f-47d1-bea0-ff2433acf744'></div>
# <div id='00ec5c49-5d74-49e5-a040-80827091f065'></div>
# <div id='d07ef53c-9f41-4b4c-9a44-39b1c012e669'></div>
# <div id='02a9f1e1-eaec-45b6-9ff9-a593b9674c34'></div>
# <div id='957addd2-754e-498e-8a43-b55b68ecf29d'></div>
# <div id='8b27cc44-30bf-4543-a14a-118416f5c41c'></div>
# <div id='336d8875-8688-4cf7-8499-b527a969976a'></div>
# <div id='4cb1285c-d60b-4f5c-8d47-77ec8b46ec59'></div>
# <div id='2fbac6a0-26f1-4be8-990a-0b93320d3944'></div>
